# %% [markdown]
# # **Informe de las elecciones generales 2023 para presidente en la Ciudad Autonoma de Buenos Aires**
#
# En el siguiente informe realizaremos un analisis de los resultados de las últimas elecciones en CABA para la Libertad Avanza con la intención de ofrecerle un panorama que le permitira utilizar las estrategias adecuadas para poder afrontar el ballotage contra Union por la Patria

# %% [markdown]
# # **Resultados electorales**
#
# ![image.png](data:image/png;base64,...)![image.png]

# %% [markdown]
# La Libertad avanza quedó como tercera fuerza en las elecciones presidenciales en la Ciudad obteniendo un 19,84 % frente a un 32,27% de Sergio Massa y un 41,22 % de Patricia Bullrich

# %% [markdown]
# # **Distribución de votos por Comuna**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Estudio del Electorado y votantes de la LLA**

# %% [markdown]
# En el primer mapa, observaremos los barrios con mayor cantidad de electores de CABA para pensar como encarar el Ballotage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Asi es que se distribuyen esos barrios en comunas:

# %% [markdown]
# Al trabajar con la base de datos del INDEC de "porcentaje de hogares con NBI al año 2010 en Ciudad Autonoma de Buenos Aires", logramos observar que las comunas que registran los porcentajes mas altos, son aquellas donde el oficialismo del PRO obtuvo sus peores resultados y en donde tanto UxP como LLA lograron capitalizar la mayor cantidad de votos debido a la disconformidad de los vecinos con la ineficacia de la gestión por cumplir sus necesidades basicas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sin embargo, UxP logró mejores resultados que LLA en las comunas resaltadas que serán fundamentales de cara al ballotage. Al analizar diferentes variables, detectamos que una de las cuestiones de este resultado fueron las relacionadas al genero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mediante un analisis del sexo de los electores de cada circuito electoral. Logramos identificar que la mayor cantidad de votantes femeninas se encuentran en la zona Sur y Este del distrito, que tambien son aquellas mas afectadas por la desigualdad economica y social. El discurso en contra de la ideologia de genero y machista de LLA fue un factor para que UxP logre sacar una ventaja en estos sectores del distrito.

# %% [markdown]
# # **¿Donde se deben ir a buscar los votos de cara al ballotage?: Lo que debe hacer La Libertad Avanza**

# %% [markdown]
# El mayor caudal de votos que pertenece a Juntos por el Cambio, deberá elegir por una de las dos opciones. En el siguiente mapa presentaremos donde se encuentra la mayor concentración de estos votos para apuntar e intensificar la campaña en dichas comunas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por su parte, la recomendación, en caso de no dar marcha atras con los discursos en contra del feminismo y la ideologia de genero, es dar una mayor participación a las referentes del espacio en busca de la identificación de las electoras con el partido, aunque la variable del genero no influirá tanto de cara al ballotage ya que se disputarán comunas con UxP donde predominan el votante hombre de JxC que tiene una distancia ideologica menor con LLA que con UxP.

# %% [markdown]
# # **Muestra para la investigación:**
#
# **Universo:** Electorado de CABA en las Elecciones generales 2023
#
# **Unidad de análisis: **Votantes de CABA
#
# **Unidad de muestreo: **Votante de CABA
#
# **Extensión espacial:** Ciudad Autonoma de Buenos Aires
#
# **Extensión temporal:** Desde el lunes 23 de octubre hasta el 1 de Noviembre
#
# **Marco Muestral**
#
# **Lista de unidades de muestreo: **Padrón Electoral 2023
#
# **Tipo de Muestreo:** Probabilístico
#
# **Procedimiento de muestreo**: Conglomerados por barrios (23 unidades de muestreo por conglomerado)
#
# **Tamaño de la Muestra:**

# %%
import math

poblacion = 2526676
nivel_confianza = 0.95
margen_error = 0.03


z_valor = 1.96
p = 0.5
e = margen_error

n = ((z_valor**2) * p * (1 - p)) / (e**2)


print("El tamaño de la población es", poblacion)

print("El nivel de confianza es de 95% y el margen de error del 3%")

print(f"Tamaño de muestra: {math.ceil(n)}")
# Out:
# El tamaño de la población es 2526676
# El nivel de confianza es de 95% y el margen de error del 3%
# Tamaño de muestra: 1068

# %% [markdown]
# **Diagrama DER para trabajar con el censo**![Diagrama Entidad-Relación 2.drawio.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
